# %% [markdown]
# # Graphing CSV File
# > Graphing CSV File
# - toc: true
# - categories: []
# - type: ap
# - week: 29

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
str_filename = 'files/basketball.csv'

# %%
fh = open(str_filename)
csv_reader = csv.reader(fh)

# %%
csv_header = next(csv_reader)
csv_header
# Out:
# ['Team',
#  ' 2019_Season',
#  ' 2020_Season',
#  ' 2021_Season',
#  ' 2022_Season',
#  ' 2023_Season']

# %%
lst_dt_csv = next(csv_reader)
lst_dt_csv
# Out:
# ['Atlanta Hawks', ' 29', ' 25', ' 47', ' 43', ' 41']

# %%
dt_csv = np.array(list(map((datetime.fromisoformat, lst_dt_csv[1:3]))))
dt_csv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dt_csv = np.array(list(map((datetime.fromisoformat, lst_dt_csv[1:3]))))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> dt_csv
#
# TypeError: map() must have at least two arguments.

# %%
lst_fgs = next(csv_reader)
np_d_fs = np.array(list(map(float, lst_fs[1:3])))
np_d_fs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> lst_fgs = next(csv_reader)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> np_d_fs = np.array(list(map(float, lst_fs[1:3])))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> np_d_fs
#
# NameError: name 'lst_fs' is not defined

# %%
fh.close()

# %%
df_sig = pd.read_csv(str_filename, header=None, skiprows=0, names=csv_header)
df_sig
# Out:
#                       Team   2019_Season   2020_Season   2021_Season  \
# 0                     Team   2019_Season   2020_Season   2021_Season
# 1            Atlanta Hawks            29            25            47
# 2           Boston Celtics            49            55            41
# 3            Brooklyn Nets            42            40            55
# 4        Charlotte Hornets            39            29            38
# 5            Chicago Bulls            22            28            35
# 6      Cleveland Cavaliers            19            24            25
# 7         Dallas Mavericks            33            47            48
# 8           Denver Nuggets            54            52            54
# 9          Detroit Pistons            41            25            23
# 10   Golden State Warriors            57            20            44
# 11         Houston Rockets            53            50            19
# 12          Indiana Pacers            48            51            39
# 13    Los Angeles Clippers            48            56            54
# 14      Los Angeles Lakers            37            60            48
# 15       Memphis Grizzlies            33            38            43
# 16              Miami Heat            39            49            46
# 17         Milwaukee Bucks            60            63            52
# 18  Minnesota Timberwolves            36            24            26
# 19    New Orleans Pelicans            33            34            35
# 20         New York Knicks            17            26            47
# 21   Oklahoma City Thunder            49            50            25
# 22           Orlando Magic            42            37            24
# 23      Philadelphia 76ers            51            48            56
# 24            Phoenix Suns            19            38            58
# 25  Portland Trail Blazers            53            39            48
# 26        Sacramento Kings            39            35            35
# 27       San Antonio Spurs            48            37            38
# 28         Toronto Raptors            58            60            31
# 29               Utah Jazz            50            50            59
# 30      Washington Wizards            32            29            39
#
#      2022_Season   2023_Season
# 0    2022_Season   2023_Season
# 1             43            41
# 2             51            57
# 3             44            45
# 4             43            27
# 5             46            40
# 6             44            51
# 7             52            38
# 8             48            53
# 9             23            17
# 10            53            44
# 11            20            22
# 12            25            35
# 13            42            44
# 14            33            43
# 15            56            51
# 16            53            44
# 17            51            58
# 18            46            42
# 19            36            42
# 20            37            47
# 21            24            40
# 22            22            34
# 23            51            54
# 24            64            45
# 25            27            33
# 26            30            48
# 27            34            22
# 28            48            41
# 29            49            37
# 30            35            35

# %%
df_sig.CH1.plot()
plt.xlabel('Sample number')
plt.ylabel('Signal value, volts')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_sig.CH1.plot()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.xlabel('Sample number')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/soham/vscode/T3Project/_notebooks/2023-5-14-PandasNATM.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.ylabel('Signal value, volts')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'CH1'

# %%
# Import the necessary modules
import matplotlib.pyplot as plt
import pandas as pd


# Initialize the lists for X and Y
data = pd.read_csv('files/basketball.csv')

df = pd.DataFrame(data)

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

# Plot the data using bar() method
plt.bar(X, Y, color='g')
plt.title("Wins by Each NBA Team")
plt.xlabel("Teams")
plt.ylabel("Number of Students")
plt.xticks(rotation=90)

# Show the plot
plt.show()
